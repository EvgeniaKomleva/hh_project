# %% [markdown]
# Цель: Получить резюме кандидатов из компаний, в которых наблюдается массовый отток сотрудников.
#
# Задача: Реализовать скрипт в Python, возвращающий список резюме сооискателей по принципу совпадения текущего/последнего места работы кандидатов.
# Необходимо определить компании, у которых текущие/бывшие сотрудники сейчас размещают резюме. И вывести резюме в сортировке по компаниям, где таких кандидатов больше всего.
# Скрипт должен поддерживать конфигурирование основных параметров поиска(ключевые слова, глубину, проф.область, город итд. Некоторые параметры, такие как проф.область="ит.телеком" и город="Москва" можно преднастроить по умолчанию).
#
# К сожалению, поиск резюме в API отсутсвует, доступен лишь просмотр резюме через метод https://api.hh.ru/resumes/
# Для поиска предлагается использовать подход с парсингом сайта и получением идентификаторов резюме с использованием библиотек Selenium и BeatifualSoap (на основе сформированного поиского запроса к web-версии сайта, например https://hh.ru/search/resume?text=JAVA&st=resumeSearch&logic=normal&pos=full_text&exp_period=all_time&exp_company_size=any&exp_industry=any&area=113&relocation=living_or_relocation&salary_from=&salary_to=&currency_code=RUR&experience=between1And3&education=higher&age_from=&age_to=&gender=unknown&employment=full&schedule=fullDay&language=eng.b1&order_by=relevance&search_period=30&items_on_page=100 ) .
# Далее идентификаторы можно просматривать в цикле и формировать из них массив данных (предварительно авторизовавшись с использованием токена корпоративной учетной записи).

# %%
import pandas as pd
import pymorphy2, re
from nltk.tokenize import sent_tokenize
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer 
from collections import Counter
import json

data = pd.read_json('data/data9.json')
data.head()
# Out:
#                                                title  \
# 0                   Контент-менеджер, SEO-копирайтер
# 1                                     UX UI дизайнер
# 2                               Frontend-разработчик
# 3                   Специалист технической поддержки
# 4  Менеджер по работе с ключевыми клиентами/Key A...
#
#                                                 href  \
# 0  /resume/83b80647000207fafd0039ed1f613278383979...
# 1  /resume/d65527fd000407fd190039ed1f393639565568...
# 2  /resume/f3861e99000500e4300039ed1f4a54464f4234...
# 3  /resume/e43c9f5800056c1a550039ed1f4d4f78426a42...
# 4  /resume/88615e580006803b7b0039ed1f5a4237496872...
#
#                                      last_work_plase
# 0                                   ООО "Кораблик-Р"
# 1                                  СОЮЗПАК, МПФ, ООО
# 2  Индивидуальное предпринимательство / частная п...
# 3                                       Софт Компани
# 4                                         Greenworks

# %%
data["href"] = 'https://hh.ru'+data["href"]

# %%
data.head()
# Out:
#                                                title  \
# 0                   Контент-менеджер, SEO-копирайтер
# 1                                     UX UI дизайнер
# 2                               Frontend-разработчик
# 3                   Специалист технической поддержки
# 4  Менеджер по работе с ключевыми клиентами/Key A...
#
#                                                 href  \
# 0  https://hh.ru/resume/83b80647000207fafd0039ed1...
# 1  https://hh.ru/resume/d65527fd000407fd190039ed1...
# 2  https://hh.ru/resume/f3861e99000500e4300039ed1...
# 3  https://hh.ru/resume/e43c9f5800056c1a550039ed1...
# 4  https://hh.ru/resume/88615e580006803b7b0039ed1...
#
#                                      last_work_plase
# 0                                   ООО "Кораблик-Р"
# 1                                  СОЮЗПАК, МПФ, ООО
# 2  Индивидуальное предпринимательство / частная п...
# 3                                       Софт Компани
# 4                                         Greenworks

# %%
count_company = data["last_work_plase"].value_counts()
df_count_company = pd.DataFrame({'last_work_plase':count_company.index, 'count':count_company.values})
df_count_company.head()
# Out:
#                                      last_work_plase  count
# 0  Индивидуальное предпринимательство / частная п...    177
# 1                                           Сбербанк     46
# 2                                            Фриланс     38
# 3                                         Ростелеком     27
# 4                        Мобильные ТелеСистемы (МТС)     25

# %%
data_with_count = data.set_index('last_work_plase').join(df_count_company.set_index('last_work_plase'))
data_with_count.head()
# Out:
#                                                        title  \
# last_work_plase
#   Омега                        Мастер по ремонту компьютеров
#  ИНТЕНШЕН                            Системный администратор
#  Интернет-Магазины                       Интернет-маркетолог
#  ОО «ИЦ»                             Системный администратор
# "A Serial" Ltd (HBO - Russia)                  IT Specialist
#
#                                                                             href  \
# last_work_plase
#   Омега                        https://hh.ru/resume/1ead0b9c0007e8cbb00039ed1...
#  ИНТЕНШЕН                      https://hh.ru/resume/6e58864a000285dccc0039ed1...
#  Интернет-Магазины             https://hh.ru/resume/4e5432c300072145b80039ed1...
#  ОО «ИЦ»                       https://hh.ru/resume/bc91f04400033060aa0039ed1...
# "A Serial" Ltd (HBO - Russia)  https://hh.ru/resume/1d9f76f80002a3e1a30039ed1...
#
#                                count
# last_work_plase
#   Омега                          1.0
#  ИНТЕНШЕН                        1.0
#  Интернет-Магазины               1.0
#  ОО «ИЦ»                         1.0
# "A Serial" Ltd (HBO - Russia)    1.0

# %%
sorted_data = data_with_count.sort_values(by=["count"], ascending=False)
sorted_data.to_csv('data_sort.csv', sep='\t', index=False)

# %%
sorted_data.head(10)
# Out:
#                                                                                                 title  \
# last_work_plase
# Индивидуальное предпринимательство / частная пр...                                Инженер-программист
# Индивидуальное предпринимательство / частная пр...                 Приходящий системный администратор
# Индивидуальное предпринимательство / частная пр...            Full stack разработчик (React, Node.js)
# Индивидуальное предпринимательство / частная пр...                                         Сценарист
# Индивидуальное предпринимательство / частная пр...                  Web-дизайнер/Frontend-разработчик
# Индивидуальное предпринимательство / частная пр...  SEO-специалист (продвижение сайтов, порталов, ...
# Индивидуальное предпринимательство / частная пр...  Веб-дизайнер, UX/UI дизайнер, Дизайнер интерфе...
# Индивидуальное предпринимательство / частная пр...  системный администратор, тех поддержка, безопа...
# Индивидуальное предпринимательство / частная пр...                                   HTML-верстальщик
# Индивидуальное предпринимательство / частная пр...                       Frontend-разработчик (React)
#
#                                                                                                  href  \
# last_work_plase
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/ea3ad192000074a1640039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/61f5e94000005697c30039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/98538ca50003492cb20039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/bca7233e0007e6cd110039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/656b79ee00063fe8fd0039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/abe763f300016cde520039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/10eb923b000694f2610039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/b1f64db00007e24e2d0039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/dc4d793a0007da80e00039ed1...
# Индивидуальное предпринимательство / частная пр...  https://hh.ru/resume/1e12edf50007c559520039ed1...
#
#                                                     count
# last_work_plase
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0
# Индивидуальное предпринимательство / частная пр...  177.0

# %%
sorted_data.to_csv('sorted_data.csv', sep='\t', index=False)
